# %% [markdown]
# # __How to import data and external custom packages from Drive?__
#
# ## __1 Step:__
# <font size=4>
#
# You need to mount (_to access/give permission_) your drive in the Colab notebook using the command above.

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# ## __2 Step:__
# <font size=4>
#
# To import custom packages (the _toolbox_ module), we have to use the _sys.path.insert()_ function to assert the path __before__ importing the package.

# %%
import sys
sys.path.insert(0, '/content/drive/MyDrive/Colab Notebooks')

from toolbox import arruma_dados

# %% [markdown]
# ## __3 Step__:
# <font size=4>
#
# Import your data using any Python module, but be aware of the data path!
#
# Notebooks are typically located in the __"Colab Notebooks"__ directory. In my case, the data file _"column_2C_weka.csv"_ is inside this directory.

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/column_2C_weka.csv')

df.head()
# Out:
#    pelvic_incidence  pelvic_tilt numeric  lumbar_lordosis_angle  sacral_slope  \
# 0         63.027817            22.552586              39.609117     40.475232
# 1         39.056951            10.060991              25.015378     28.995960
# 2         68.832021            22.218482              50.092194     46.613539
# 3         69.297008            24.652878              44.311238     44.644130
# 4         49.712859             9.652075              28.317406     40.060784
#
#    pelvic_radius  degree_spondylolisthesis     class
# 0      98.672917                 -0.254400  Abnormal
# 1     114.405425                  4.564259  Abnormal
# 2     105.985135                 -3.530317  Abnormal
# 3     101.868495                 11.211523  Abnormal
# 4     108.168725                  7.918501  Abnormal

# %% [markdown]
# ## __In summary:__
# <font size=4>
#
# We can organize all packages, for instance, as following.

# %%
from google.colab import drive
drive.mount('/content/drive/')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow import keras

import sys
sys.path.insert(0, '/content/drive/MyDrive/Colab Notebooks')

from toolbox import arruma_dados
